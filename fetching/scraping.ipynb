# %% [markdown]
# ### Scraping

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import os
import time
import random
chromedriver = "/Applications/chromedriver"
os.environ["webdriver.chrome.driver"] = chromedriver
driver = webdriver.Chrome(chromedriver)

# %% [markdown]
# #### Get the links to the products

# %%
def get_links():
    time.sleep(1)
    hrefs = []
    links = driver.find_elements_by_css_selector('div.SkuGrid a')
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight/2);")
    time.sleep(2)
    links = driver.find_elements_by_css_selector('div.SkuGrid a')
    for link in links:
        url = link.get_attribute('href')
        hrefs.append(url)
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    time.sleep(2)

    links = driver.find_elements_by_css_selector('div.SkuGrid a')
    for link in links:
        url = link.get_attribute('href')
        hrefs.append(url)
    return hrefs

# %%
start_urls = ['http://www.sephora.com/face-makeup?currentPage={}'.format(page) for page in range(1, 16)]

# %%
hrefs = []

# %%
for url in start_urls[2:]:
    driver.get(url)
    links = get_links()
    print(len(links))
    for link in links:
        if link not in hrefs:
            hrefs.append(link)
            print (link)

# %% [markdown]
# **remove duplicates**

# %%
hrefs = list(set(hrefs))

# %% [markdown]
# #### pickling

# %%
import pickle
import pandas as pd
import re

# %%
# pickle.dump(hrefs, open('links.pkl', 'wb'))
hrefs = pickle.load(open('data/links.pkl', 'rb'))

# %% [markdown]
# ### Getting URLs for cheek, eye, and lip

# %%
def add_links(base_url, max_page):
    start_urls = [base_url + str(page) for page in range(1, max_page + 1)]
    for url in start_urls:
        driver.get(url)
        links = get_links()
        print(len(links))
        for link in links:
            if link not in hrefs:
                hrefs.append(link)
                print(link)

# %%
add_links('http://www.sephora.com/eye-makeup?currentPage=', 15)

# %%
add_links('http://www.sephora.com/cheek-makeup?currentPage=', 7)

# %%
add_links('http://www.sephora.com/lips-makeup?currentPage=', 9)

# %%
len(hrefs)
# Out:
# 836

# %% [markdown]
# ### Scraping Product

# %%
df_p = pd.DataFrame(columns=['product_id', 'product_name', 'brand_name', 'img_url',
                             'product_url',
                             'size', 'rev_count', 'love_count', 'categories', 'keywords', 'brand_info', 'use',
                             'ingredients', 'description', 'details'])

# %%
df_c = pd.DataFrame(columns=['username', 'product_id', 'status', 'location',
                             'skin_tone', 'eye_color',
                             'age', 'title', 'body', 'helpful',
                             'not_helpful', 'star_count', 'date', ])

# %%
df_v = pd.DataFrame(columns=['product_id', 'finish',
                             'img_url', 'color'])

# %% [markdown]
# #### Helper Functions

# %%
def selenium_scrape(qry, obj, method='xpath', many=False, attribute=None):
    q = None
    if method == 'xpath':
        q = obj.find_elements_by_xpath(qry)
    elif method == 'css':
        q = obj.find_elements_by_css_selector(qry)
    
    if attribute == 'click':
        if q:
            q[0].click()
            return True
        else:
            return False
    if q:
        if attribute:
            if many:
                return [el.get_attribute(attribute) for el in q]
            return q[0].get_attribute(attribute)
        if many:
            return [el.text for el in q]
        return q[0].text
    return ''
def random_sleep(long=False):
    if long:
        time.sleep(10 + random.random())
    time.sleep(0.5 + random.random())

# %% [markdown]
# #### scraping

# %%
def scrape_item():
    item = {}
    item['categories'] = ';'.join(selenium_scrape('li.Breadcrumb-item', driver, 'css', True))
    item['keywords'] = selenium_scrape('//meta[@name="keywords"]', driver, attribute='content')
    item['brand_name'] = selenium_scrape('//meta[@property="product:brand"]', driver, attribute='content')
    item['product_name'] = selenium_scrape('//h1', driver).split('\n')[-1]
    item['rev_count'] = selenium_scrape('//a[@href="#pdp-reviews"]/span', driver)
    item['love_count'] = selenium_scrape('//span[@seph-love-count]', driver)
    item['product_id'] = selenium_scrape('//meta[@property="product:id"]', driver, attribute='content')
    item['size'] = selenium_scrape('div.InfoRow > span.InfoRow-size > span.InfoRow-value', driver, 'css')
    item['price'] = selenium_scrape('//meta[@property="product:price"]', driver, attribute='content')
    item['img_url'] = selenium_scrape('//meta[@property="og:image"]', driver, attribute='content')
    item['description'] = selenium_scrape('//meta[@property="og:description"]', driver, attribute='content')
    item['product_url'] = selenium_scrape('//meta[@property="og:url"]', driver, attribute='content')
    success = False
    while not success:
        try:
            if selenium_scrape('//span[contains(text(), "Details")]', driver, attribute='click'):
                item['details'] = selenium_scrape('div#details', driver, 'css')
            if selenium_scrape('//span[contains(text(), "Ingredients")]', driver, attribute='click'):
                item['ingredients'] = selenium_scrape('div#ingredients', driver, 'css')
            if selenium_scrape('//span[contains(text(), "How to Use")]', driver, attribute='click'):
                item['use'] = selenium_scrape('div#use', driver, 'css')
            if selenium_scrape('//span[contains(text(), "About the Brand")]', driver, attribute='click'): 
                item['brand_info'] = selenium_scrape('div#brand', driver, 'css')
            success = True
        except:
            print('Error')
    return item['product_id'], pd.DataFrame([item])

# %%
def scrape_swatches(p_id):
    data = []
    for f_group in driver.find_elements_by_css_selector('div.PdpLayout-main div.SwatchGroup'):
        finish = selenium_scrape('span', f_group, method='css')
        imgs = selenium_scrape('img.Swatch-img', f_group, method='css', many=True, attribute='src')
        start = df_v.shape[1]
        p_id = item['product_id']
        for img in imgs:
            data.append([p_id, finish, img, ''])
    return pd.DataFrame(data, columns=df_v.columns)

# %%
def scrape_comments(p_id):
    users = {}
    users['username'] = selenium_scrape('//span[@itemprop="author"]', driver, many=True)
    users['body'] = selenium_scrape('//div[@itemprop="description"]', driver, many=True)
    users['title'] = selenium_scrape('span.BVRRReviewTitle', driver, method='css', many=True)
    users['date'] = selenium_scrape('span.BVRRReviewDate', driver, method='css', many=True)
    users['not_helpful'] = selenium_scrape('span.BVDI_FVNegative span.BVDILinkSpan span.BVDINumber', driver, method='css', many=True)
    users['helpful'] = selenium_scrape('span.BVDI_FVPositive span.BVDILinkSpan span.BVDINumber', driver, method='css', many=True)
    users['star_count'] = selenium_scrape('#BVRRDisplayContentID div.BVRRRatingNormalImage > img', driver, method='css', many=True, attribute='alt')
    users['skin_tone'] = []
    users['eye_color'] = []
    users['status'] = []
    users['age'] = []
    users['location'] = []

    for el in driver.find_elements_by_css_selector('#BVRRDisplayContentID .BVRRReviewDisplayStyle3Summary'):
        # location
        location = ''
        if el.find_elements_by_css_selector('div.BVRRUserLocationContainer'):
            location = el.find_element_by_css_selector('span.BVRRUserLocation').text
        # skintone
        skintone = ''
        if el.find_elements_by_css_selector('div.BVRRContextDataValueskinToneContainer'):
            skintone = el.find_element_by_css_selector('span.BVRRContextDataValueskinTone').text
        # eye color 
        eye_color = ''
        if el.find_elements_by_css_selector('div.BVRRContextDataValueeyeColorContainer'):
            eye_color = el.find_element_by_css_selector('span.BVRRContextDataValueeyeColor').text
        # age
        age = ''
        if el.find_elements_by_css_selector('div.BVRRContextDataValueageContainer'):
            age = el.find_element_by_css_selector('span.BVRRContextDataValueage').text

        badges = ''
        if el.find_elements_by_css_selector('div.BVRRBadges'):
            badges = el.find_element_by_css_selector('div.BVRRBadges > div').get_attribute('class')
        users['skin_tone'].append(skintone)
        users['eye_color'].append(eye_color)
        users['status'].append(badges)
        users['age'].append(age)
        users['location'].append(location)
    users['product_id'] = [p_id] * len(users['username'])
    return pd.DataFrame(users)

# %%
for no, url in enumerate(hrefs):
    driver.get(url)
    random_sleep()
    print('scraping {}'.format(url))
    p_id, item = scrape_item()
    df_p = df_p.append(item)
    df_v = df_v.append(scrape_swatches(p_id))
    df_c = df_c.append(scrape_comments(p_id))
    last_page = selenium_scrape('.BVRRPageNumber', driver, method='css', many=True)
    comment_base_url = selenium_scrape('.BVRRPageLink a', driver, method='css', attribute='href')
    print(comment_base_url)
    if comment_base_url:
        last_page = int(last_page[-1])
    else:
        last_page = 1
    print('last page is {}'.format(last_page))
    comment_base_url = re.sub(r'page\=(\d+)', 'page={}', comment_base_url)
    for page in range(2, last_page + 1):
        print('scraping comment page {}/{}'.format(page, last_page))
        com_url = comment_base_url.format(page)
        com_page = requests.get(com_url)
        soup = BeautifulSoup(com_page.text, 'html.parser')
        df_c = df_c.append(scrape.scrape_users(soup, p_id))
    if no % 15 == 0:
        random_sleep(long=True)
        driver = webdriver.Chrome(chromedriver)
        save_progress()
# Out:
# scraping http://www.sephora.com/brow-powder-duo-P69300?skuId=929778&icid2=products%20grid:p69300
# http://reviews.sephora.com/8723abredes/P69300/reviews.htm?format=embedded&page=2&scrollToTop=true
# last page is 745
# scraping comment page 2/745
# scraping comment page 3/745
# scraping comment page 4/745
# scraping comment page 5/745
# scraping comment page 6/745
# scraping comment page 7/745
# scraping comment page 8/745
# scraping comment page 9/745
# scraping comment page 10/745
# scraping comment page 11/745
# scraping comment page 12/745
# scraping comment page 13/745
# scraping comment page 14/745
# scraping comment page 15/745
# scraping comment page 16/745
# scraping comment page 17/745
# scraping comment page 18/745
# scraping comment page 19/745
# scraping comment page 20/745
# scraping comment page 21/745
# scraping comment page 22/745
# scraping comment page 23/745
# scraping comment page 24/745
# scraping comment page 25/745
# scraping comment page 26/745
# scraping comment page 27/745
# scraping comment page 28/745
# scraping comment page 29/745
# scraping comment page 30/745
# scraping comment page 31/745
# scraping comment page 32/745
# scraping comment page 33/745
# scraping comment page 34/745
# scraping comment page 35/745
# scraping comment page 36/745
# scraping comment page 37/745
# scraping comment page 38/745
# scraping comment page 39/745
# scraping comment page 40/745
# scraping comment page 41/745
# scraping comment page 42/745
# scraping comment page 43/745
# scraping comment page 44/745
# scraping comment page 45/745
# scraping comment page 46/745
# scraping comment page 47/745
# scraping comment page 48/745
# scraping comment page 49/745
# scraping comment page 50/745
# scraping comment page 51/745
# scraping comment page 52/745
# scraping comment page 53/745
# scraping comment page 54/745
# scraping comment page 55/745
# scraping comment page 56/745
# scraping comment page 57/745
# scraping comment page 58/745
# scraping comment page 59/745
# scraping comment page 60/745
# scraping comment page 61/745
# scraping comment page 62/745
# scraping comment page 63/745
# scraping comment page 64/745
# scraping comment page 65/745
# scraping comment page 66/745
# scraping comment page 67/745
# scraping comment page 68/745
# scraping comment page 69/745
# scraping comment page 70/745
# scraping comment page 71/745
# scraping comment page 72/745
# scraping comment page 73/745
# scraping comment page 74/745
# scraping comment page 75/745
# scraping comment page 76/745
# scraping comment page 77/745
# scraping comment page 78/745
# scraping comment page 79/745
# scraping comment page 80/745
# scraping comment page 81/745
# scraping comment page 82/745
# scraping comment page 83/745
# scraping comment page 84/745
# scraping comment page 85/745
# scraping comment page 86/745
# scraping comment page 87/745
# scraping comment page 88/745
# scraping comment page 89/745
# scraping comment page 90/745
# scraping comment page 91/745
# scraping comment page 92/745
# scraping comment page 93/745
# scraping comment page 94/745
# scraping comment page 95/745
# scraping comment page 96/745
# scraping comment page 97/745
# scraping comment page 98/745
# scraping comment page 99/745
# scraping comment page 100/745
# scraping comment page 101/745
# scraping comment page 102/745
# scraping comment page 103/745
# scraping comment page 104/745
# scraping comment page 105/745
# scraping comment page 106/745
# scraping comment page 107/745
# scraping comment page 108/745
# scraping comment page 109/745
# scraping comment page 110/745
# scraping comment page 111/745
# scraping comment page 112/745
# scraping comment page 113/745
# scraping comment page 114/745
# scraping comment page 115/745
# scraping comment page 116/745
# scraping comment page 117/745
# scraping comment page 118/745
# scraping comment page 119/745
# scraping comment page 120/745
# scraping comment page 121/745
# scraping comment page 122/745
# scraping comment page 123/745
# scraping comment page 124/745
# scraping comment page 125/745
# scraping comment page 126/745
# scraping comment page 127/745
# scraping comment page 128/745
# scraping comment page 129/745
# scraping comment page 130/745
# scraping comment page 131/745
# scraping comment page 132/745
# scraping comment page 133/745
# scraping comment page 134/745
# scraping comment page 135/745
# scraping comment page 136/745
# scraping comment page 137/745
# scraping comment page 138/745
# scraping comment page 139/745
# scraping comment page 140/745
# scraping comment page 141/745
# scraping comment page 142/745
# scraping comment page 143/745
# scraping comment page 144/745
# scraping comment page 145/745
# scraping comment page 146/745
# scraping comment page 147/745
# scraping comment page 148/745
# scraping comment page 149/745
# scraping comment page 150/745
# scraping comment page 151/745
# scraping comment page 152/745
# scraping comment page 153/745
# scraping comment page 154/745
# scraping comment page 155/745
# scraping comment page 156/745
# scraping comment page 157/745
# scraping comment page 158/745
# scraping comment page 159/745
# scraping comment page 160/745
# scraping comment page 161/745
# scraping comment page 162/745
# scraping comment page 163/745
# scraping comment page 164/745
# scraping comment page 165/745
# scraping comment page 166/745
# scraping comment page 167/745
# scraping comment page 168/745
# scraping comment page 169/745
# scraping comment page 170/745
# scraping comment page 171/745
# scraping comment page 172/745
# scraping comment page 173/745
# scraping comment page 174/745
# scraping comment page 175/745
# scraping comment page 176/745
# scraping comment page 177/745
# scraping comment page 178/745
# scraping comment page 179/745
# scraping comment page 180/745
# scraping comment page 181/745
# scraping comment page 182/745
# scraping comment page 183/745
# scraping comment page 184/745
# scraping comment page 185/745
# scraping comment page 186/745
# scraping comment page 187/745
# scraping comment page 188/745
# scraping comment page 189/745
# scraping comment page 190/745
# scraping comment page 191/745
# scraping comment page 192/745
# scraping comment page 193/745
# scraping comment page 194/745
# scraping comment page 195/745
# scraping comment page 196/745
# scraping comment page 197/745
# scraping comment page 198/745
# scraping comment page 199/745
# scraping comment page 200/745
# scraping comment page 201/745
# scraping comment page 202/745
# scraping comment page 203/745
# scraping comment page 204/745
# scraping comment page 205/745
# scraping comment page 206/745
# scraping comment page 207/745
# scraping comment page 208/745
# scraping comment page 209/745
# scraping comment page 210/745
# scraping comment page 211/745
# scraping comment page 212/745
# scraping comment page 213/745
# scraping comment page 214/745
# scraping comment page 215/745
# scraping comment page 216/745
# scraping comment page 217/745
# scraping comment page 218/745
# scraping comment page 219/745
# scraping comment page 220/745
# scraping comment page 221/745
# scraping comment page 222/745
# scraping comment page 223/745
# scraping comment page 224/745
# scraping comment page 225/745
# scraping comment page 226/745
# scraping comment page 227/745
# scraping comment page 228/745
# scraping comment page 229/745
# scraping comment page 230/745
# scraping comment page 231/745
# scraping comment page 232/745
# scraping comment page 233/745
# scraping comment page 234/745
# scraping comment page 235/745
# scraping comment page 236/745
# scraping comment page 237/745
# scraping comment page 238/745
# scraping comment page 239/745
# scraping comment page 240/745
# scraping comment page 241/745
# scraping comment page 242/745
# scraping comment page 243/745
# scraping comment page 244/745
# scraping comment page 245/745
# scraping comment page 246/745
# scraping comment page 247/745
# scraping comment page 248/745
# scraping comment page 249/745
# scraping comment page 250/745
# scraping comment page 251/745
# scraping comment page 252/745
# scraping comment page 253/745
# scraping comment page 254/745
# scraping comment page 255/745
# scraping comment page 256/745
# scraping comment page 257/745
# scraping comment page 258/745
# scraping comment page 259/745
# scraping comment page 260/745
# scraping comment page 261/745
# scraping comment page 262/745
# scraping comment page 263/745
# scraping comment page 264/745
# scraping comment page 265/745
# scraping comment page 266/745
# scraping comment page 267/745
# scraping comment page 268/745
# scraping comment page 269/745
# scraping comment page 270/745
# scraping comment page 271/745
# scraping comment page 272/745
# scraping comment page 273/745
# scraping comment page 274/745
# scraping comment page 275/745
# scraping comment page 276/745
# scraping comment page 277/745
# scraping comment page 278/745
# scraping comment page 279/745
# scraping comment page 280/745
# scraping comment page 281/745
# scraping comment page 282/745
# scraping comment page 283/745
# scraping comment page 284/745
# scraping comment page 285/745
# scraping comment page 286/745
# scraping comment page 287/745
# scraping comment page 288/745
# scraping comment page 289/745
# scraping comment page 290/745
# scraping comment page 291/745
# scraping comment page 292/745
# scraping comment page 293/745
# scraping comment page 294/745
# scraping comment page 295/745
# scraping comment page 296/745
# scraping comment page 297/745
# scraping comment page 298/745
# scraping comment page 299/745
# scraping comment page 300/745
# scraping comment page 301/745
# scraping comment page 302/745
# scraping comment page 303/745
# scraping comment page 304/745
# scraping comment page 305/745
# scraping comment page 306/745
# scraping comment page 307/745
# scraping comment page 308/745
# scraping comment page 309/745
# scraping comment page 310/745
# scraping comment page 311/745
# scraping comment page 312/745
# scraping comment page 313/745
# scraping comment page 314/745
# scraping comment page 315/745
# scraping comment page 316/745
# scraping comment page 317/745
# scraping comment page 318/745
# scraping comment page 319/745
# scraping comment page 320/745
# scraping comment page 321/745
# scraping comment page 322/745
# scraping comment page 323/745
# scraping comment page 324/745
# scraping comment page 325/745
# scraping comment page 326/745
# scraping comment page 327/745
# scraping comment page 328/745
# scraping comment page 329/745
# scraping comment page 330/745
# scraping comment page 331/745
# scraping comment page 332/745
# scraping comment page 333/745
# scraping comment page 334/745
# scraping comment page 335/745
# scraping comment page 336/745
# scraping comment page 337/745
# scraping comment page 338/745
# scraping comment page 339/745
# scraping comment page 340/745
# scraping comment page 341/745
# scraping comment page 342/745
# scraping comment page 343/745
# scraping comment page 344/745
# scraping comment page 345/745
# scraping comment page 346/745
# scraping comment page 347/745
# scraping comment page 348/745
# scraping comment page 349/745
# scraping comment page 350/745
# scraping comment page 351/745
# scraping comment page 352/745
# scraping comment page 353/745
# scraping comment page 354/745
# scraping comment page 355/745
# scraping comment page 356/745
# scraping comment page 357/745
# scraping comment page 358/745
# scraping comment page 359/745
# scraping comment page 360/745
# scraping comment page 361/745
# scraping comment page 362/745
# scraping comment page 363/745
# scraping comment page 364/745
# scraping comment page 365/745
# scraping comment page 366/745
# scraping comment page 367/745
# scraping comment page 368/745
# scraping comment page 369/745
# scraping comment page 370/745
# scraping comment page 371/745
# scraping comment page 372/745
# scraping comment page 373/745
# scraping comment page 374/745
# scraping comment page 375/745
# scraping comment page 376/745
# scraping comment page 377/745
# scraping comment page 378/745
# scraping comment page 379/745
# scraping comment page 380/745
# scraping comment page 381/745
# scraping comment page 382/745
# scraping comment page 383/745
# scraping comment page 384/745
# scraping comment page 385/745
# scraping comment page 386/745
# scraping comment page 387/745
# scraping comment page 388/745
# scraping comment page 389/745
# scraping comment page 390/745
# scraping comment page 391/745
# scraping comment page 392/745
# scraping comment page 393/745
# scraping comment page 394/745
# scraping comment page 395/745
# scraping comment page 396/745
# scraping comment page 397/745
# scraping comment page 398/745
# scraping comment page 399/745
# scraping comment page 400/745
# scraping comment page 401/745
# scraping comment page 402/745
# scraping comment page 403/745
# scraping comment page 404/745
# scraping comment page 405/745
# scraping comment page 406/745
# scraping comment page 407/745
# scraping comment page 408/745
# scraping comment page 409/745
# scraping comment page 410/745
# scraping comment page 411/745
# scraping comment page 412/745
# scraping comment page 413/745
# scraping comment page 414/745
# scraping comment page 415/745
# scraping comment page 416/745
# scraping comment page 417/745
# scraping comment page 418/745
# scraping comment page 419/745
# scraping comment page 420/745
# scraping comment page 421/745
# scraping comment page 422/745
# scraping comment page 423/745
# scraping comment page 424/745
# scraping comment page 425/745
# scraping comment page 426/745
# scraping comment page 427/745
# scraping comment page 428/745
# scraping comment page 429/745
# scraping comment page 430/745
# scraping comment page 431/745
# scraping comment page 432/745
# scraping comment page 433/745
# scraping comment page 434/745
# scraping comment page 435/745
# scraping comment page 436/745
# scraping comment page 437/745
# scraping comment page 438/745
# scraping comment page 439/745
# scraping comment page 440/745
# scraping comment page 441/745
# scraping comment page 442/745
# scraping comment page 443/745
# scraping comment page 444/745
# scraping comment page 445/745
# scraping comment page 446/745
# scraping comment page 447/745
# scraping comment page 448/745
# scraping comment page 449/745
# scraping comment page 450/745
# scraping comment page 451/745
# scraping comment page 452/745
# scraping comment page 453/745
# scraping comment page 454/745
# scraping comment page 455/745
# scraping comment page 456/745
# scraping comment page 457/745
# scraping comment page 458/745
# scraping comment page 459/745
# scraping comment page 460/745
# scraping comment page 461/745
# scraping comment page 462/745
# scraping comment page 463/745
# scraping comment page 464/745
# scraping comment page 465/745
# scraping comment page 466/745
# scraping comment page 467/745
# scraping comment page 468/745
# scraping comment page 469/745
# scraping comment page 470/745
# scraping comment page 471/745
# scraping comment page 472/745
# scraping comment page 473/745
# scraping comment page 474/745
# scraping comment page 475/745
# scraping comment page 476/745
# scraping comment page 477/745
# scraping comment page 478/745
# scraping comment page 479/745
# scraping comment page 480/745
# scraping comment page 481/745
# scraping comment page 482/745
# scraping comment page 483/745
# scraping comment page 484/745
# scraping comment page 485/745
# scraping comment page 486/745
# scraping comment page 487/745
# scraping comment page 488/745
# scraping comment page 489/745
# scraping comment page 490/745
# scraping comment page 491/745
# scraping comment page 492/745
# scraping comment page 493/745
# scraping comment page 494/745
# scraping comment page 495/745
# scraping comment page 496/745
# scraping comment page 497/745
# scraping comment page 498/745
# scraping comment page 499/745
# scraping comment page 500/745
# scraping comment page 501/745
# scraping comment page 502/745
# scraping comment page 503/745
# scraping comment page 504/745
# scraping comment page 505/745
# scraping comment page 506/745
# scraping comment page 507/745
# scraping comment page 508/745
# scraping comment page 509/745
# scraping comment page 510/745
# scraping comment page 511/745
# scraping comment page 512/745
# scraping comment page 513/745
# scraping comment page 514/745
# scraping comment page 515/745
# scraping comment page 516/745
# scraping comment page 517/745
# scraping comment page 518/745
# scraping comment page 519/745
# scraping comment page 520/745
# scraping comment page 521/745
# scraping comment page 522/745
# scraping comment page 523/745
# scraping comment page 524/745
# scraping comment page 525/745
# scraping comment page 526/745
# scraping comment page 527/745
# scraping comment page 528/745
# scraping comment page 529/745
# scraping comment page 530/745
# scraping comment page 531/745
# scraping comment page 532/745
# scraping comment page 533/745
# scraping comment page 534/745
# scraping comment page 535/745
# scraping comment page 536/745
# scraping comment page 537/745
# scraping comment page 538/745
# scraping comment page 539/745
# scraping comment page 540/745
# scraping comment page 541/745
# scraping comment page 542/745
# scraping comment page 543/745
# scraping comment page 544/745
# scraping comment page 545/745
# scraping comment page 546/745
# scraping comment page 547/745
# scraping comment page 548/745
# scraping comment page 549/745
# scraping comment page 550/745
# scraping comment page 551/745
# scraping comment page 552/745
# scraping comment page 553/745
# scraping comment page 554/745
# scraping comment page 555/745
# scraping comment page 556/745
# scraping comment page 557/745
# scraping comment page 558/745
# scraping comment page 559/745
# scraping comment page 560/745
# scraping comment page 561/745
# scraping comment page 562/745
# scraping comment page 563/745
# scraping comment page 564/745
# scraping comment page 565/745
# scraping comment page 566/745
# scraping comment page 567/745
# scraping comment page 568/745
# scraping comment page 569/745
# scraping comment page 570/745
# scraping comment page 571/745
# scraping comment page 572/745
# scraping comment page 573/745
# scraping comment page 574/745
# scraping comment page 575/745
# scraping comment page 576/745
# scraping comment page 577/745
# scraping comment page 578/745
# scraping comment page 579/745
# scraping comment page 580/745
# scraping comment page 581/745
# scraping comment page 582/745
# scraping comment page 583/745
# scraping comment page 584/745
# scraping comment page 585/745
# scraping comment page 586/745
# scraping comment page 587/745
# scraping comment page 588/745
# scraping comment page 589/745
# scraping comment page 590/745
# scraping comment page 591/745
# scraping comment page 592/745
# scraping comment page 593/745
# scraping comment page 594/745
# scraping comment page 595/745
# scraping comment page 596/745
# scraping comment page 597/745
# scraping comment page 598/745
# scraping comment page 599/745
# scraping comment page 600/745
# scraping comment page 601/745
# scraping comment page 602/745
# scraping comment page 603/745
# scraping comment page 604/745
# scraping comment page 605/745
# scraping comment page 606/745
# scraping comment page 607/745
# scraping comment page 608/745
# scraping comment page 609/745
# scraping comment page 610/745
# scraping comment page 611/745
# scraping comment page 612/745
# scraping comment page 613/745
# scraping comment page 614/745
# scraping comment page 615/745
# scraping comment page 616/745
# scraping comment page 617/745
# scraping comment page 618/745
# scraping comment page 619/745
# scraping comment page 620/745
# scraping comment page 621/745
# scraping comment page 622/745
# scraping comment page 623/745
# scraping comment page 624/745
# scraping comment page 625/745
# scraping comment page 626/745
# scraping comment page 627/745
# scraping comment page 628/745
# scraping comment page 629/745
# scraping comment page 630/745
# scraping comment page 631/745
# scraping comment page 632/745
# scraping comment page 633/745
# scraping comment page 634/745
# scraping comment page 635/745
# scraping comment page 636/745
# scraping comment page 637/745
# scraping comment page 638/745
# scraping comment page 639/745
# scraping comment page 640/745
# scraping comment page 641/745
# scraping comment page 642/745
# scraping comment page 643/745
# scraping comment page 644/745
# scraping comment page 645/745
# scraping comment page 646/745
# scraping comment page 647/745
# scraping comment page 648/745
# scraping comment page 649/745
# scraping comment page 650/745
# scraping comment page 651/745
# scraping comment page 652/745
# scraping comment page 653/745
# scraping comment page 654/745
# scraping comment page 655/745
# scraping comment page 656/745
# scraping comment page 657/745
# scraping comment page 658/745
# scraping comment page 659/745
# scraping comment page 660/745
# scraping comment page 661/745
# scraping comment page 662/745
# scraping comment page 663/745
# scraping comment page 664/745
# scraping comment page 665/745
# scraping comment page 666/745
# scraping comment page 667/745
# scraping comment page 668/745
# scraping comment page 669/745
# scraping comment page 670/745
# scraping comment page 671/745
# scraping comment page 672/745
# scraping comment page 673/745
# scraping comment page 674/745
# scraping comment page 675/745
# scraping comment page 676/745
# scraping comment page 677/745
# scraping comment page 678/745
# scraping comment page 679/745
# scraping comment page 680/745
# scraping comment page 681/745
# scraping comment page 682/745
# scraping comment page 683/745
# scraping comment page 684/745
# scraping comment page 685/745
# scraping comment page 686/745
# scraping comment page 687/745
# scraping comment page 688/745
# scraping comment page 689/745
# scraping comment page 690/745
# scraping comment page 691/745
# scraping comment page 692/745
# scraping comment page 693/745
# scraping comment page 694/745
# scraping comment page 695/745
# scraping comment page 696/745
# scraping comment page 697/745
# scraping comment page 698/745
# scraping comment page 699/745
# scraping comment page 700/745
# scraping comment page 701/745
# scraping comment page 702/745
# scraping comment page 703/745
# scraping comment page 704/745
# scraping comment page 705/745
# scraping comment page 706/745
# scraping comment page 707/745
# scraping comment page 708/745
# scraping comment page 709/745
# scraping comment page 710/745
# scraping comment page 711/745
# scraping comment page 712/745
# scraping comment page 713/745
# scraping comment page 714/745
# scraping comment page 715/745
# scraping comment page 716/745
# scraping comment page 717/745
# scraping comment page 718/745
# scraping comment page 719/745
# scraping comment page 720/745
# scraping comment page 721/745
# scraping comment page 722/745
# scraping comment page 723/745
# scraping comment page 724/745
# scraping comment page 725/745
# scraping comment page 726/745
# scraping comment page 727/745
# scraping comment page 728/745
# scraping comment page 729/745
# scraping comment page 730/745
# scraping comment page 731/745
# scraping comment page 732/745
# scraping comment page 733/745
# scraping comment page 734/745
# scraping comment page 735/745
# scraping comment page 736/745
# scraping comment page 737/745
# scraping comment page 738/745
# scraping comment page 739/745
# scraping comment page 740/745
# scraping comment page 741/745
# scraping comment page 742/745
# scraping comment page 743/745
# scraping comment page 744/745
# scraping comment page 745/745
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-ac5de076b28b> in <module>()
#      25         random_sleep(long=True)
#      26         driver = webdriver.Chrome(chromedriver)
# ---> 27         save_progress()
#      28
#
# NameError: name 'save_progress' is not defined

# %%
from libs import scrape
from bs4 import BeautifulSoup
import requests

# %% [markdown]
# ### Save progress

# %%
def save_progress():
    df_c.to_csv('data/comments.csv', index=None)
    df_p.to_csv('data/products.csv', index=None)
    df_v.to_csv('data/variations.csv', index=None)

# %%
# df_c = pd.read_csv('data/comments.csv')
# df_p = pd.read_csv('data/products.csv')
# df_v = pd.read_csv('data/variations.csv')

# %%
save_progress()
